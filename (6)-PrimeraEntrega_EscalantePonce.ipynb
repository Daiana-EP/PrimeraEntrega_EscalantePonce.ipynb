# %% [markdown]
# **Coder House**
#
# *Data Sciente Comisión 42400*
#
# *Dataset: EcoBicis de la ciudad de Buenos Aires*
#
# *Alumna: Daiana Escalante Ponce*
#
# *Tutor: Luciano Ceballos*
#
# *Profesora: Rebeca Figueroa*

# %% [markdown]
# # **EcoBicis de la ciudad de Bs As 2022**

# %% [markdown]
# ## **Abstracto con motivación y audiencia**

# %% [markdown]
# **MOTIVACIÓN Y AUDIENCIA:**
#
# La Conferencia de las Naciones Unidas en 1972 sobre el Medio Humano, en Estocolmo (Suecia), fue la primera conferencia mundial en hacer visible la conciencia colectiva por el cuidado del planeta. Desde entonces se han emitido más de un millar de leyes para proteger el medioambiente. Las políticas ambientales son muy diversas y dependen en gran medida de las características y necesidades de cada región. Sin embargo, en los últimos años el mundo ha marcado objetivos comunes para hacer frente al mayor desafío: el cambio climático.
#
# En un mundo en constante evolución, donde los desafíos medioambientales y urbanos se vuelven cada vez más urgentes, me vi motivada en estudiar el sistema de Ecobicis de la Ciudad de Buenos Aires para comprender cómo podemos avanzar hacia un futuro más sustentable. Esta iniciativa no solo promueve un medio ambiente más limpio, sino que también sienta las bases para la construcción de ciudades comprometidas con la ecología y el bienestar de sus habitantes.
#
# Por otro lado, la audiencia del mismo pueden ser dos grupos: los ciudadanos de Argentina y/o el gobierno de las ciudades de nuestro país. El primer grupo puede leer el trabajo para entender acerca de las ciudades sustentables y por qué el sistema de EcoBicis apunta a ello. El segundo grupo puede leer el trabajo para tomar decisiones acerca de cómo mejorar el programa.
#
# **¿CUÁL ES LA FINALIDAD DE LAS ECOBICIS DE LA CIUDAD DE BUENOS AIRES?**
#
# El fomento del uso de la bicicleta como medio de transporte hace al propósito de transformar Buenos Aires en una ciudad más verde, inclusiva, creativa e innovadora. Un estudio anterior al lanzamiento del programa Ecobici indicó que los porteños tenían en sus casas un millón de bicicletas pero que para la mayoría era un recuerdo de la infancia, por eso se buscó proyectar una ciudad donde la bicicleta sea una verdadera alternativa de transporte rápido, ecológico y saludable. Para ello se ha incorporado una red de ciclovías integradas y protegidas, que conectan puntos principales de la ciudad.
#
# El programa Ecobici es un sistema de bicicletas compartidas que funciona en la Ciudad de Buenos Aires, cuenta con 340 estaciones y 3.600 rodados que en 2023 alcanzó más de 112.000 usuarios activos. Para utilizar el sistema es necesario realizar un registro previo, con tarjeta de crédito o débito.
#
# Actualmente el sistema está presente en 47 de los 48 barrios de la Ciudad Autónoma de Buenos Aires, funcionando los 365 días del año 24 horas.

# %% [markdown]
# ## **Preguntas/hipotesis/objetivos**

# %% [markdown]
# **OBJETIVOS:**
#
# En primer lugar, teniendo en cuenta que uno de los objetivos del sistema de EcoBicis es implementar un medio de tranporte ecológico para los porteños, tomamos como principal objetivo de este trabajo el brindar información relevante de usuarios y recorridos hechos para mejorar el servicio haciendo así un aporte para encaminar la ciudad a una que cuide más el medioambiente.
#
# En segundo lugar, buscaremos predecir la cantidad de minutos que duran los viajes para poder distribuir mejor las bicicletas nuevas adquiridas.
#
# **HIPÓTESIS DE TRABAJO:**
#
# Un estudio presentado por ClosinGap y liderado por L'Oréal en España determinó que la mujer tiene mayor conciencia ambiental y adopta comportamientos más sostenibles que el hombre. Por eso la **Hipótesis 1** que se presenta es que "*Las mujeres y disidencias realizan más viajes en comparación a varones*" ya que son personas con tendencia al cuidado del medioambiente, teniendo en cuenta que una de las razones de fomentación de la EcoBici es usar un medio de transporte más ecológico.
#
# Cuando se piensa en fomentar la EcoBici como un medio de transporte rápido, ecológico y saludable, se habla de usar las bicicletas para conectar puntos de la ciudad que no deberían estar muy lejos entre sí. Por esta razón la **Hipótesis 2** dice que "*El promedio de duración de viajes se encuentra entre 15 y 20 min*", esto aseguraría que no sean usadas para la recreación y sólo usadas para recurrir a lugares puntuales.
#
# Como habitante del interior del país, no conozco muy bien la ciudad de Bs As, pero en los momentos que me ha tocado ir pude notar la cantidad de personas y medios de transporte que rondan por toda la ciudad. La **Hipótesis 3** viene de la mano de esa percepción que tengo que es que "*El lugar con más recorridos se encuentran en el barrio Palermo*"; para esto tenemos en cuenta que en dicho barrio están las siguientes estaciones: Estación Plaza Güemes, Plaza Italia, Estación Pacífico.

# %% [markdown]
# ## **Contexto comercial, Problema Comercial, Contexto analítico**

# %% [markdown]
# **Contexto empresarial:** Somos un grupo de científico de datos en una gran organización que brinda informes al gobierno de la Ciudad de Buenos Aires. En este caso analizaremos los datos del sistema de EcoBicis pero fuimos contratados este año (2023), es decir que no fuimos la empresa que comenzó con la recolección de datos por eso debemos conocerlos desde el principio.
#
# Los DataFrame con los que vamos a trabajar contiene los datos de las EcoBicis de la ciudad de Buenos Aires, estos están divididos en dos partes: usuarios registrados y viajes realizados; cada uno de ellos se dividen por años.
#
# **Problema comercial:** El gobierno de la Ciudad de Buenos Aires quiere adquirir mayor número de bicicletas para usar en este medio de transporte, el problema es que no saben dónde sería más estratégico colocarlas. Para esto, se buscará predecir la cantidad de minutos que son usadas cada bici y así colocar más donde haya más demanda y más inicios/fines de recorridos.
#
# **Contexto analítico:** Obtenemos los datos de EcoBicis de la página del gobierno de la Ciudad de Buenos Aires, están divididos en dos partes: usuarios registrados (por año) y viajes realizados (por año). El primer dataset contiene información personal de cada usuario que se da de alta:  id, género, fecha de alta, hora de alta y si agregó dni. El segundo dataset contiene información de los viajes realizados en toda la ciudad con datos relacionados a las estaciones de origen y final de recorridos, duración del viaje, ubicación geoespacial de las estaciones involucradas en los recorridos, modelo de bicicleta utilizada, etc. Como nuestra finalidad es conocer acerca de los recorridos, sólo usaremos estos últimos tipos de datasets.
#
# Además, usaremos análisis de gráficos de barras, circulares y de caja para responder a la problématica y las hipótesis planteadas.

# %% [markdown]
# ## **Lectura de los csv**

# %% [markdown]
# Estos datasets son extraídos de la página del gobierno de la ciudad de Buenos Aires. En este proyecto se usarán lo relacionado a los recorridos de las EcoBicis usadas desde 2021 al 2023.
#
# Realizamos la lectura de los csv por año y hacemos las modificaciones necesarias para luego hacer sólo un DataFrame que recopile todos los datos sin problemas, tomando como base las columnas presentes en el dataset del 2023.

# %%
#Importar librerías
import numpy as np
from sklearn.datasets import fetch_openml
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.feature_selection import SequentialFeatureSelector

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Configurar Pandas para mostrar el formato decimal regular y no como notación científica
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
pip install mlxtend

# %% [markdown]
# ## **Recorridos**

# %% [markdown]
# #### **Recorridos del 2023:**

# %%
# Leer el archivo ecobicis_trips_2023 que está en la carpeta Coder_Data_Science
df_23 = pd.read_csv ('/content/drive/MyDrive/Cursos_Data/Coder_Data_Science/Datasets/recorridos-realizados-2023.csv',thousands = ',')

# Muestra los primeros registos
df_23.head(3)
# Out:
#         Id_recorrido  duracion_recorrido fecha_origen_recorrido  \
# 0  17910696BAEcobici                1848    2023-04-24 10:30:10
# 1  17600256BAEcobici                 288    2023-03-22 17:40:55
# 2  17255670BAEcobici                1103    2023-02-15 23:12:22
#
#   id_estacion_origen        nombre_estacion_origen  \
# 0       358BAEcobici                  249 - Balbín
# 1       444BAEcobici  061 - Ministerio de Economia
# 2       280BAEcobici           222 - SIMON BOLIVAR
#
#            direccion_estacion_origen  long_estacion_origen  \
# 0                        2519 Conesa                -58.47
# 1  Balcarce e Yrigoyen, Hipolito Av.                -58.37
# 2   1701 Fernandez Moreno, Baldomero                -58.45
#
#    lat_estacion_origen fecha_destino_recorrido id_estacion_destino  \
# 0               -34.56     2023-04-24 11:00:58        278BAEcobici
# 1               -34.61     2023-03-22 17:45:43          3BAEcobici
# ...

# %% [markdown]
# #### Datos nulos del 2023:

# %%
df_23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1689754 entries, 0 to 1689753
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   Id_recorrido                1689754 non-null  object
#  1   duracion_recorrido          1689754 non-null  int64
#  2   fecha_origen_recorrido      1689754 non-null  object
#  3   id_estacion_origen          1689754 non-null  object
#  4   nombre_estacion_origen      1689754 non-null  object
#  5   direccion_estacion_origen   1689754 non-null  object
#  6   long_estacion_origen        1689754 non-null  float64
#  7   lat_estacion_origen         1689754 non-null  float64
#  8   fecha_destino_recorrido     1689754 non-null  object
#  9   id_estacion_destino         1689754 non-null  object
#  10  nombre_estacion_destino     1689754 non-null  object
#  11  direccion_estacion_destino  1689754 non-null  object
# ...

# %% [markdown]
# Como podemos notar, la columna género tiene 8012 valores nulos; como se trata de una columna categórica, debemos reemplazar los faltantes con la moda.

# %%
# Calcula la moda de la columna 'género'
moda = df_23['género'].mode()[0]
print("La moda es: ", moda)

# Reemplaza los valores NaN en la columna 'género' por la moda
df_23['género'].fillna(moda, inplace=True)

# Verifica la columna 'género' después del reemplazo
valores_unicos = df_23['género'].unique()
print("los valores únicos son: ", valores_unicos)
# Out:
# La moda es:  MALE
# los valores únicos son:  ['MALE' 'FEMALE' 'OTHER']

# %%
df_23.isnull().sum()
# Out:
# Id_recorrido                  0
# duracion_recorrido            0
# fecha_origen_recorrido        0
# id_estacion_origen            0
# nombre_estacion_origen        0
# direccion_estacion_origen     0
# long_estacion_origen          0
# lat_estacion_origen           0
# fecha_destino_recorrido       0
# id_estacion_destino           0
# nombre_estacion_destino       0
# direccion_estacion_destino    0
# long_estacion_destino         0
# lat_estacion_destino          0
# id_usuario                    0
# modelo_bicicleta              0
# género                        0
# dtype: int64

# %% [markdown]
# #### **Recorridos del 2022:**

# %%
# Leer el archivo ecobicis_trips_2022 que está en la carpeta Coder_Data_Science
df_22 = pd.read_csv ('/content/drive/MyDrive/Cursos_Data/Coder_Data_Science/Datasets/recorridos-realizados-2022.csv',thousands = ',')

# Muestra los primeros registos
df_22.head(3)
# Out:
#    Unnamed: 0  X       Id_recorrido  duracion_recorrido  \
# 0           1  1  13267975BAEcobici                2610
# 1           2  2  13268526BAEcobici                 545
# 2           3  3  13268400BAEcobici                2061
#
#   fecha_origen_recorrido id_estacion_origen nombre_estacion_origen  \
# 0    2022-01-16 14:58:42         5BAEcobici     005 - Plaza Italia
# 1    2022-01-16 17:26:27        51BAEcobici          051 - TUCUMAN
# 2    2022-01-16 16:51:12       161BAEcobici        161 - Humahuaca
#
#   direccion_estacion_origen  long_estacion_origen  lat_estacion_origen  \
# 0        Av. Sarmiento 2601                -58.42               -34.58
# 1  Tucuman & 9 De Julio Av.                -58.38               -34.60
# 2            3912 Humahuaca                -58.42               -34.60
#
#   fecha_destino_recorrido id_estacion_destino        nombre_estacion_destino  \
# 0     2022-01-16 15:42:12        210BAEcobici          335 - General Urquiza
# ...

# %% [markdown]
# En este caso, para que df_22 quede como df_23 debemos:
#
# *   Quitar columna: `Unnamed: 0`
# *   Quitar columna: `X`
# *   Cambiar de nombre la columna: `Género`

# %%
# Borra las columnas "Unnamed: 0" y "X"
df_22.drop('Unnamed: 0', axis=1, inplace=True)
df_22.drop('X', axis=1, inplace=True)

# Cambia de nombre la columna "Género" por "género"
nuevo_nombre = {'Género': 'género'}
df_22.rename(columns=nuevo_nombre, inplace=True)

df_22.head(3)
# Out:
#         Id_recorrido  duracion_recorrido fecha_origen_recorrido  \
# 0  13267975BAEcobici                2610    2022-01-16 14:58:42
# 1  13268526BAEcobici                 545    2022-01-16 17:26:27
# 2  13268400BAEcobici                2061    2022-01-16 16:51:12
#
#   id_estacion_origen nombre_estacion_origen direccion_estacion_origen  \
# 0         5BAEcobici     005 - Plaza Italia        Av. Sarmiento 2601
# 1        51BAEcobici          051 - TUCUMAN  Tucuman & 9 De Julio Av.
# 2       161BAEcobici        161 - Humahuaca            3912 Humahuaca
#
#    long_estacion_origen  lat_estacion_origen fecha_destino_recorrido  \
# 0                -58.42               -34.58     2022-01-16 15:42:12
# 1                -58.38               -34.60     2022-01-16 17:35:32
# 2                -58.42               -34.60     2022-01-16 17:25:33
#
#   id_estacion_destino        nombre_estacion_destino  \
# 0        210BAEcobici          335 - General Urquiza
# ...

# %% [markdown]
# #### Datos nulos del 2022:

# %%
df_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2922805 entries, 0 to 2922804
# Data columns (total 17 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Id_recorrido                object
#  1   duracion_recorrido          int64
#  2   fecha_origen_recorrido      object
#  3   id_estacion_origen          object
#  4   nombre_estacion_origen      object
#  5   direccion_estacion_origen   object
#  6   long_estacion_origen        float64
#  7   lat_estacion_origen         float64
#  8   fecha_destino_recorrido     object
#  9   id_estacion_destino         object
#  10  nombre_estacion_destino     object
#  11  direccion_estacion_destino  object
#  12  long_estacion_destino       float64
#  13  lat_estacion_destino        float64
#  14  id_usuario                  object
#  15  modelo_bicicleta            object
#  16  género                      object
# dtypes: float64(4), int64(1), object(12)
# memory usage: 379.1+ MB

# %%
df_22.isnull().sum()
# Out:
# Id_recorrido                      0
# duracion_recorrido                0
# fecha_origen_recorrido            0
# id_estacion_origen                0
# nombre_estacion_origen            0
# direccion_estacion_origen         0
# long_estacion_origen              0
# lat_estacion_origen               0
# fecha_destino_recorrido           0
# id_estacion_destino               0
# nombre_estacion_destino           0
# direccion_estacion_destino        0
# long_estacion_destino             0
# lat_estacion_destino              0
# id_usuario                        0
# modelo_bicicleta                  0
# género                        16306
# dtype: int64

# %% [markdown]
# Como podemos notar, la columna género tiene 16306 valores nulos; como se trata de una columna categórica, debemos reemplazar los faltantes con la moda.

# %%
# Calcula la moda de la columna 'género'
moda = df_22['género'].mode()[0]
print("La moda es: ", moda)

# Reemplaza los valores NaN en la columna 'género' por la moda
df_22['género'].fillna(moda, inplace=True)

# Verifica la columna 'género' después del reemplazo
valores_unicos = df_22['género'].unique()
print("los valores únicos son: ", valores_unicos)
# Out:
# La moda es:  MALE
# los valores únicos son:  ['FEMALE' 'MALE' 'OTHER']

# %% [markdown]
# #### **Recorridos del 2021:**

# %%
# Leer el archivo ecobicis_trips_2021 que está en la carpeta Coder_Data_Science
df_21 = pd.read_csv ('/content/drive/MyDrive/Cursos_Data/Coder_Data_Science/Datasets/recorridos-realizados-2021.csv',thousands = ',')

# Muestra los primeros registos
df_21.head(3)
# Out:
# <ipython-input-14-186abe175e7c>:2: DtypeWarning: Columns (17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_21 = pd.read_csv ('/content/drive/MyDrive/Cursos_Data/Coder_Data_Science/Datasets/recorridos-realizados-2021.csv',thousands = ',')
#    Unnamed: 0      Id_recorrido  duracion_recorrido fecha_origen_recorrido  \
# 0           1  9920899BAEcobici                2026    2021-01-26 19:58:12
# 1           2  9918792BAEcobici                1474    2021-01-26 17:37:33
# 2           3  9917121BAEcobici                 629    2021-01-26 15:24:59
#
#   id_estacion_origen                 nombre_estacion_origen  \
# 0        86BAEcobici                         086 - SAAVEDRA
# 1       197BAEcobici            197 - PLAZA CIUDAD DE UDINE
# 2       165BAEcobici  165 - PLAZA MONSEÑOR MIGUEL DE ANDREA
#
#                           direccion_estacion_origen  long_estacion_origen  \
# 0                                     1019 Saavedra                -58.40
# ...

# %% [markdown]
# En este caso, para que df_21 quede como df_23 debemos:
#
# *   Quitar columna: `Unnamed: 0`
# *   Quitar columna: `Género`

# %%
# Borra las columnas "Unnamed: 0" y "Género"
df_21.drop('Unnamed: 0', axis=1, inplace=True)
df_21.drop('Género', axis=1, inplace=True)

df_21.head(3)
# Out:
#        Id_recorrido  duracion_recorrido fecha_origen_recorrido  \
# 0  9920899BAEcobici                2026    2021-01-26 19:58:12
# 1  9918792BAEcobici                1474    2021-01-26 17:37:33
# 2  9917121BAEcobici                 629    2021-01-26 15:24:59
#
#   id_estacion_origen                 nombre_estacion_origen  \
# 0        86BAEcobici                         086 - SAAVEDRA
# 1       197BAEcobici            197 - PLAZA CIUDAD DE UDINE
# 2       165BAEcobici  165 - PLAZA MONSEÑOR MIGUEL DE ANDREA
#
#                           direccion_estacion_origen  long_estacion_origen  \
# 0                                     1019 Saavedra                -58.40
# 1                                     Mercedes 1480                -58.49
# 2  Dr Tomas Manuel De  Anchorena &  Jose A. Cabrera                -58.41
#
#    lat_estacion_origen fecha_destino_recorrido id_estacion_destino  \
# 0               -34.62     2021-01-26 20:31:58          8BAEcobici
# ...

# %% [markdown]
# #### Datos nulos del 2021:

# %%
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2860091 entries, 0 to 2860090
# Data columns (total 17 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Id_recorrido                object
#  1   duracion_recorrido          int64
#  2   fecha_origen_recorrido      object
#  3   id_estacion_origen          object
#  4   nombre_estacion_origen      object
#  5   direccion_estacion_origen   object
#  6   long_estacion_origen        float64
#  7   lat_estacion_origen         float64
#  8   fecha_destino_recorrido     object
#  9   id_estacion_destino         object
#  10  nombre_estacion_destino     object
#  11  direccion_estacion_destino  object
#  12  long_estacion_destino       float64
#  13  lat_estacion_destino        object
#  14  id_usuario                  object
#  15  modelo_bicicleta            object
#  16  género                      object
# dtypes: float64(3), int64(1), object(13)
# memory usage: 371.0+ MB

# %%
df_21.isnull().sum()
# Out:
# Id_recorrido                        0
# duracion_recorrido                  0
# fecha_origen_recorrido              0
# id_estacion_origen                  0
# nombre_estacion_origen              0
# direccion_estacion_origen           0
# long_estacion_origen                0
# lat_estacion_origen                 0
# fecha_destino_recorrido             0
# id_estacion_destino                 0
# nombre_estacion_destino             0
# direccion_estacion_destino          0
# long_estacion_destino               0
# lat_estacion_destino                0
# id_usuario                          0
# modelo_bicicleta                    0
# género                        1562106
# dtype: int64

# %% [markdown]
# Como podemos notar, la columna género tiene 1562106 valores nulos; como se trata de una columna categórica, debemos reemplazar los faltantes con la moda.

# %%
# Calcula la moda de la columna 'género'
moda = df_21['género'].mode()[0]
print("La moda es: ", moda)

# Reemplaza los valores NaN en la columna 'género' por la moda
df_21['género'].fillna(moda, inplace=True)

# Verifica la columna 'género' después del reemplazo
valores_unicos = df_21['género'].unique()
print("los valores únicos son: ", valores_unicos)
# Out:
# La moda es:  MALE
# los valores únicos son:  ['OTHER' 'FEMALE' 'MALE']

# %% [markdown]
# ## **Creación del DataFrame de recorridos**

# %%
# Se concatenan los datasets de recorridos en uno solo llamado "df"
df = pd.concat([df_21, df_22, df_23], axis=0)

# Cambio la columna 'duracion_recorrido' de segundo a minutos
df['duracion_recorrido'] = df['duracion_recorrido'] / 60
df.head()
# Out:
#        Id_recorrido  duracion_recorrido fecha_origen_recorrido  \
# 0  9920899BAEcobici               33.77    2021-01-26 19:58:12
# 1  9918792BAEcobici               24.57    2021-01-26 17:37:33
# 2  9917121BAEcobici               10.48    2021-01-26 15:24:59
# 3  9919277BAEcobici               10.27    2021-01-26 18:11:22
# 4  9921579BAEcobici               11.40    2021-01-26 20:38:30
#
#   id_estacion_origen                 nombre_estacion_origen  \
# 0        86BAEcobici                         086 - SAAVEDRA
# 1       197BAEcobici            197 - PLAZA CIUDAD DE UDINE
# 2       165BAEcobici  165 - PLAZA MONSEÑOR MIGUEL DE ANDREA
# 3        20BAEcobici             020 - DISTRITO AUDIOVISUAL
# 4        44BAEcobici                        044 - Ecoparque
#
#                           direccion_estacion_origen  long_estacion_origen  \
# 0                                     1019 Saavedra                -58.40
# ...

# %%
#Forma del DataFrame df
print("Estructura de dataframe:", df.shape)
print(" ")
df.info()
# Out:
# Estructura de dataframe: (7472650, 17)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7472650 entries, 0 to 1689753
# Data columns (total 17 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Id_recorrido                object
#  1   duracion_recorrido          float64
#  2   fecha_origen_recorrido      object
#  3   id_estacion_origen          object
#  4   nombre_estacion_origen      object
#  5   direccion_estacion_origen   object
#  6   long_estacion_origen        float64
#  7   lat_estacion_origen         float64
#  8   fecha_destino_recorrido     object
#  9   id_estacion_destino         object
#  10  nombre_estacion_destino     object
#  11  direccion_estacion_destino  object
#  12  long_estacion_destino       float64
#  13  lat_estacion_destino        object
#  14  id_usuario                  object
#  15  modelo_bicicleta            object
#  16  género                      object
# dtypes: float64(4), object(13)
# ...

# %%
df.isnull().sum()
# Out:
# Id_recorrido                  0
# duracion_recorrido            0
# fecha_origen_recorrido        0
# id_estacion_origen            0
# nombre_estacion_origen        0
# direccion_estacion_origen     0
# long_estacion_origen          0
# lat_estacion_origen           0
# fecha_destino_recorrido       0
# id_estacion_destino           0
# nombre_estacion_destino       0
# direccion_estacion_destino    0
# long_estacion_destino         0
# lat_estacion_destino          0
# id_usuario                    0
# modelo_bicicleta              0
# género                        0
# dtype: int64

# %% [markdown]
# *   El dataset presenta 17 columnas y 7472650 filas.
# *   El dataset no tiene valores nulos ya que fueron tratados antes de unir los datasets.
#
# **Valores categóricos:**
#
# 1.Id_recorrido: ID que se le asigna al viaje
#
# 3.fecha_origen_recorrido: fecha y hora en la que inicia el recorrido
#
# 4.id_estacion_origen: ID de la estación donde comienza el recorrido
#
# 5.nombre_estacion_origen: nombre de la estación donde comienza el viaje
#
# 6.direccion_estacion_origen: dirección de la estación donde comienza el viaje
#
# 9.fecha_destino_recorrido: fecha y hora en la que termina el recorrido
#
# 10.id_estacion_destino: ID de la estación donde termina el recorrido
#
# 11.nombre_estacion_destino: nombre de la estación donde termina el viaje
#
# 12.direccion_estacion_destino: dirección de la estación donde termina el viaje
#
# 15.id_usuario: id del usuario que realiza el recorrido
#
# 16.modelo_bicicleta: modelo de bicicleta que se usa en el recorrido
#
# 17.género: género con el que se autopercibe el usuario, puede ser Male (masculino), Female (femenino) u Other (otro género)
#
#
# **Valores cuantitativos:**
#
# 2.duracion_recorrido: duración del recorrido en segundos
#
#
# **Valores de locación:**
#
# 7.long_estacion_origen: longitud en coordenadas geográfica donde inicia el recorrido
#
# 8.lat_estacion_origen: latitud en coordenadas geográficas donde inicia el recorrido
#
# 13.long_estacion_destino: longitud en coordenadas geográfica donde termina el recorrido
#
# 14.lat_estacion_destino: latitud en coordenadas geográficas donde termina el recorrido

# %% [markdown]
# ## **Análisis de variables numéricas**

# %%
# Como la única columna con valor numérico es "duracion_recorrido", trabajamos solo con ella
df.describe()
# Out:
#        duracion_recorrido  long_estacion_origen  lat_estacion_origen  \
# count          7472650.00            7472650.00           7472650.00
# mean                21.26                -58.42               -34.60
# std                203.48                  0.04                 0.02
# min                  1.02                -58.53               -34.68
# 25%                  9.98                -58.44               -34.61
# 50%                 16.05                -58.42               -34.60
# 75%                 25.08                -58.39               -34.58
# max             323888.55                -58.36               -34.54
#
#        long_estacion_destino
# count             7472650.00
# mean                  -49.30
# std                    11.58
# min                   -58.53
# 25%                   -58.43
# 50%                   -58.38
# 75%                   -34.61
# max                   -34.54

# %% [markdown]
# Este dataset tiene los datos de 7472650 filas recorridos, del df.describe() anterior en la variable cuantitativa duracion_recorrido tenemos:
# *  **Media y desviación estandar:** El rango de minutos por recorrido se encuentra entre (21.26 - 203.48) y (21.26 + 203.48)
# *  **Min:** El mínimo recorrido fue de 1.02 minutos.
# *   **Max :** El máximo recorrido fue de 323888.55 min
# *   **25%:** Indica que el 25% de viajes se dieron en un máximo de 9.98 min.
# *   **50% y mediana :** Indica que el 50% de viajes se dieron en un máximo de 16.05 min.
# *   **75%:** Indica que el 75% de viajes se dieron en un máximo de 25.08 min.

# %% [markdown]
# ## **Análisis exploratorios de datos (EDA)**

# %% [markdown]
# Como quiero predecir la duración de los recorridos, las cosas que me servirán analizar son:
#
# *   Cantidad de recorridos distinguidos por los meses del año
# *   Cantidad de viajes hechos por cada género en los meses del año
# *   Cantidad de viajes iniciados en las estaciones
# *   Género de las personas que realizan los recorridos
# *   Duración de los recorridos

# %% [markdown]
# ### Cantidad de viajes por mes

# %%
# Sólo quiero trabajar con el mes de los recorridos
# Armo una columna 'mes_recorrido'
df['fecha_origen_recorrido'] = pd.to_datetime(df['fecha_origen_recorrido'])
df['mes_recorrido'] = df['fecha_origen_recorrido'].dt.month

# Mostrar el DataFrame resultante con la columnas 'mes'
df.head()
# Out:
#        Id_recorrido  duracion_recorrido fecha_origen_recorrido  \
# 0  9920899BAEcobici               33.77    2021-01-26 19:58:12
# 1  9918792BAEcobici               24.57    2021-01-26 17:37:33
# 2  9917121BAEcobici               10.48    2021-01-26 15:24:59
# 3  9919277BAEcobici               10.27    2021-01-26 18:11:22
# 4  9921579BAEcobici               11.40    2021-01-26 20:38:30
#
#   id_estacion_origen                 nombre_estacion_origen  \
# 0        86BAEcobici                         086 - SAAVEDRA
# 1       197BAEcobici            197 - PLAZA CIUDAD DE UDINE
# 2       165BAEcobici  165 - PLAZA MONSEÑOR MIGUEL DE ANDREA
# 3        20BAEcobici             020 - DISTRITO AUDIOVISUAL
# 4        44BAEcobici                        044 - Ecoparque
#
#                           direccion_estacion_origen  long_estacion_origen  \
# 0                                     1019 Saavedra                -58.40
# ...

# %%
#Imprimir total de viajes por mes
print(df["mes_recorrido"].value_counts())
# Out:
# 3     821649
# 2     752192
# 1     709777
# 8     708491
# 4     704287
# 5     615293
# 11    565542
# 6     538627
# 10    530405
# 7     524532
# 9     520454
# 12    481401
# Name: mes_recorrido, dtype: int64

# %%
# Crear el countplot
plt.figure(figsize=(8, 6))

#Creamos el countplot
sns.countplot(x='mes_recorrido', data=df)

#Contextualizamos el gráfico
plt.title('Cantidad de viajes por mes')
plt.xlabel('Mes del recorrido')
plt.ylabel('Cantidad de viajes')
plt.show()

# %% [markdown]
# Como se observa en la lista de cantidad de viajes y en el gráfico, los meses 1, 2 y 8 (enero, febrero y agosto) son los que presentan mayor cantidad de recorridos.
#
# Podriamos decir que los meses de frios invernales (meses 5, 6 y 7; mayo, junio y julio) son los meses menos elegidos para realizar viajes en bicicleta.

# %% [markdown]
# ### Cantidad de viajes por género

# %%
# Crear el countplot
plt.figure(figsize=(8, 6))

#Creamos el countplot
sns.countplot(x='mes_recorrido', data=df, hue = "género")

#Contextualizamos el gráfico
plt.title('Cantidad de viajes por género')
plt.xlabel('Mes del recorrido')
plt.ylabel('Cantidad de viajes')
plt.show()

# %% [markdown]
# Si hacemos diferenciación por género, vemos que los meses más elegidos por cada uno no coinciden con la totalidad de los viajes como digimos en el apartado anterior. Hay más viajes en enero, febrero y marzo (meses 1, 2 y 3).
#
# Podriamos decir que los meses de frios invernales (meses 6 y 7; junio y julio) son los meses menos elegidos para realizar viajes en bicicleta si miramos los grupos por género.

# %% [markdown]
# ### Estación de inicio del recorrido

# %%
# Nombre de las estaciones que tienen registradas salidas
valores_unicos = df['id_estacion_origen'].unique()

# %%
# Muestra la lista de las 15 estaciones con más salidas de recorridos
df_estaciones = df['nombre_estacion_origen'].value_counts().head(15).reset_index().rename(columns={"index": "estacion",
                                                                                    "nombre_estacion_origen": "cant_viajes"})
df_estaciones.head()
# Out:
#                         estacion  cant_viajes
# 0                 014 - Pacifico        94992
# 1             147 - Constitución        84547
# 2             005 - Plaza Italia        74896
# 3  160 - Godoy Cruz y Libertador        74283
# 4                 008 - Congreso        73957

# %%
# Armo un gráfico de barras con el top 15 de estaciones
sns.barplot(data=df_estaciones, x='estacion', y='cant_viajes')
plt.xticks(rotation=45, ha='right')

plt.show() # Muestra el gráfico

# %% [markdown]
# El gráfico muestra las 15 estaciones con más viajes iniciados.
#
# Como vemos, sólo dos estaciones (Pacífico y Plaza Italia) hay del barrio de Palermo. Más allá de que están en este top 15, podemos asegurar que la hipótesis no es cierta ya que ya que otras estaciones de otros barrios son también muy concurridas.

# %% [markdown]
# ### Gráfico donde se relaciona el usuario con la cantidad de viajes hechos

# %%
# Muestra la lista de usuarios
df_usuarios = df['id_usuario'].value_counts().head(300).reset_index().rename(columns={"index": "usuario",
                                                                                    "id_usuario": "cant_viajes"})
df_usuarios.head()
# Out:
#            usuario  cant_viajes
# 0  668737BAEcobici         3010
# 1  268778BAEcobici         2547
# 2  373935BAEcobici         2235
# 3   16145BAEcobici         2098
# 4  724129BAEcobici         1880

# %%
df_usuarios.describe()
# Out:
#        cant_viajes
# count       300.00
# mean       1018.27
# std         282.61
# min         767.00
# 25%         825.50
# 50%         926.50
# 75%        1108.00
# max        3010.00

# %%
# Armo el gráfico de disperción
x = df_usuarios['usuario']
y = df_usuarios['cant_viajes']

plt.figure(figsize=(10, 6))
plt.scatter(x, y, c='blue', marker='o')
plt.title('Gráfico de dispersión con cantidad de viajes hechos por los usuarios')
plt.xlabel('Usuarios')
plt.xticks([])
plt.ylabel('Cantidad de viajes realizados')
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Selección de variables**

# %% [markdown]
# Como quiero predecir la duración de los recorridos, las cosas que me servirán analizar son:
#
# *   Cantidad de recorridos distinguidos por los meses del año
# *   Cantidad de viajes hechos por cada género en los meses del año
# *   Cantidad de viajes iniciados en las estaciones
# *   Género de las personas que realizan los recorridos
# *   Duración de los recorridos

# %% [markdown]
# Por lo tanto, las columnas que se eliminarán ya que no me aportan datos al modelo son:
#
# - Id_recorrido
# - fecha_origen_recorrido (ya que armé la columna mes_recorrido)
# - nombre_estacion_origen
# - direccion_estacion_origen
# - fecha_destino_recorrido
# - nombre_estacion_destino
# - direccion_estacion_destino
# - modelo_bicicleta

# %%
#Eliminamos columnas que no sean relevantes
df.drop(["Id_recorrido", "fecha_origen_recorrido", "nombre_estacion_origen",
          "direccion_estacion_origen", "fecha_destino_recorrido", "nombre_estacion_destino",
          "direccion_estacion_destino", "modelo_bicicleta", "id_usuario"], axis=1,inplace=True)

# %%
df.head()
# Out:
#    duracion_recorrido id_estacion_origen  long_estacion_origen  \
# 0               33.77        86BAEcobici                -58.40
# 1               24.57       197BAEcobici                -58.49
# 2               10.48       165BAEcobici                -58.41
# 3               10.27        20BAEcobici                -58.44
# 4               11.40        44BAEcobici                -58.41
#
#    lat_estacion_origen id_estacion_destino  long_estacion_destino  \
# 0               -34.62          8BAEcobici                 -34.61
# 1               -34.62          9BAEcobici                 -34.59
# 2               -34.60         13BAEcobici                 -34.61
# 3               -34.58         14BAEcobici                 -34.58
# 4               -34.58         14BAEcobici                 -34.58
#
#       lat_estacion_destino  género  mes_recorrido
# 0  -34.6094218,-58.3893364   OTHER              1
# 1    -34.585443,-58.407741   OTHER              1
# ...

# %% [markdown]
# ### Transformar etiquetas categóricas en numéricas: Género

# %%
# Reemplazo los valores de la columna de Género
palab_a_reemplazar1 = "MALE"
valor_reemplazo1 = 1

palab_a_reemplazar2 = "FEMALE"
valor_reemplazo2 = 2

palab_a_reemplazar3 = "OTHER"
valor_reemplazo3 = 3

# Cambiar los valores específicos de la columna "Edad" por la palabra de reemplazo
df['género'] = df['género'].replace(palab_a_reemplazar1, valor_reemplazo1)
df['género'] = df['género'].replace(palab_a_reemplazar2, valor_reemplazo2)
df['género'] = df['género'].replace(palab_a_reemplazar3, valor_reemplazo3)

valores_unicos2 = df['género'].unique()
print(valores_unicos2)
# Out:
# [3 2 1]

# %%
#Definir features y variable objetivo
X = df[['mes_recorrido', 'id_estacion_origen', 'género']] #Columnas que se utilizan
y = df['duracion_recorrido']  # Variable objetivo

# %%
X
# Out:
#          mes_recorrido id_estacion_origen  género
# 0                    1        86BAEcobici       3
# 1                    1       197BAEcobici       3
# 2                    1       165BAEcobici       2
# 3                    1        20BAEcobici       2
# 4                    1        44BAEcobici       2
# ...                ...                ...     ...
# 1689749              1       116BAEcobici       1
# 1689750              5        14BAEcobici       3
# 1689751              4       186BAEcobici       2
# 1689752              1        75BAEcobici       1
# 1689753              1       235BAEcobici       2
#
# [7472650 rows x 3 columns]

# %%
y
# Out:
# 0         33.77
# 1         24.57
# 2         10.48
# 3         10.27
# 4         11.40
#            ...
# 1689749   16.83
# 1689750   19.42
# 1689751   18.07
# 1689752   27.90
# 1689753   44.00
# Name: duracion_recorrido, Length: 7472650, dtype: float64

# %%
#Crear matriz de correlacion
#Concatenar X / y para visualizar correlacion entre variables
combined_df = pd.concat([X, y], axis=1)

# Calcular la matriz de correlación
correlation_matrix = combined_df.corr()
combined_df = pd.concat([X, y], axis=1)

# Calcular la matriz de correlación
correlation_matrix = combined_df.corr()

# Crear el mapa de calor para visualizar la matriz de correlación
#plt.figure(figsize=(10, 6))
sns.heatmap(data=correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Matriz de Correlación entre Características y Duración de viaje")
plt.show()
# Out:
# <ipython-input-39-9ca76ea2fb5f>:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = combined_df.corr()
# <ipython-input-39-9ca76ea2fb5f>:10: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = combined_df.corr()
